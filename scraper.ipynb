# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import time
import json
import re
import pandas as pd

import inspect
import twofourseven

# This will find all classes attached to the module
class_members = inspect.getmembers(twofourseven, inspect.isclass)

# This list will no longer be empty
print([name for name, obj in class_members])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 13
#      10 import twofourseven # This just imports the package folder
#      12 # You have to explicitly import the sub-module
# ---> 13 from twofourseven import two_fourseven
#      15 # Now, inspect the sub-module where the classes actually live
#      16 class_members = inspect.getmembers(two_fourseven, inspect.isclass)
#
# ImportError: cannot import name 'two_fourseven' from 'twofourseven' (c:\Users\User\anaconda3\envs\cfb\Lib\site-packages\twofourseven\__init__.py)
